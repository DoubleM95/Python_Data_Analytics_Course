# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_07_Pandas Merge DataFrames.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# ## 🟩 Merge US Jobs and Monthly Postings (2.7.1)

# %%
df_us_jobs = df[df['job_country'] == 'United States'].copy()
df_us_jobs['job_posted_month'] = df_us_jobs['job_posted_date'].dt.strftime('%B')

df_monthly_postings = df_us_jobs.groupby('job_posted_month')['job_country'].size().reset_index(name='postings_count')

merged_df = pd.merge(df_us_jobs, df_monthly_postings, on='job_posted_month', how='right').sort_values(by='postings_count', ascending=False)
merged_df.head()

#By Luke
# df['job_posted_month'] = df['job_posted_date'].dt.to_period('M')
# df_us_jobs = df[df['job_country'] == 'United States']
# df_monthly_postings = df_us_jobs.groupby('job_posted_month').size().reset_index(name='postings_count')
# merged_df = pd.merge(df_us_jobs, df_monthly_postings, on='job_posted_month', how='right')
# merged_df.head()
# Out:
#              job_title_short                           job_title  \
# 176811        Data Scientist                      Data scientist
# 176810  Senior Data Engineer  Senior Data Engineer - VP - Hybrid
# 176796          Data Analyst             Data Compliance Analyst
# 176797          Data Analyst                        Data Analyst
# 176798        Data Scientist               Data Integration Lead
#
#                job_location            job_via job_schedule_type  \
# 176811       Washington, DC     via Talent.com         Full-time
# 176810   Atlantic Beach, FL      via WJTV Jobs         Full-time
# 176796       Alpharetta, GA  via CareerBuilder         Full-time
# 176797  North Las Vegas, NV         via Indeed         Full-time
# 176798            Plano, TX       via LinkedIn        Contractor
#
#         job_work_from_home            search_location     job_posted_date  \
# 176811               False                    Georgia 2023-01-02 23:49:06
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Merge Non-Remote Jobs and Salary (2.7.2)

# %%
df_not_remote_jobs = df[df['job_work_from_home'] == False]
df_not_remote_salary = df_not_remote_jobs.groupby('job_title_short')['salary_year_avg'].mean().reset_index()
df_not_remote_salary.rename(columns={'salary_year_avg': 'salary_not_remote_avg'}, inplace=True)

merged_df = pd.merge(df_not_remote_jobs, df_not_remote_salary, on='job_title_short', how='right')
merged_df.head()
# Out:
#     job_title_short                                 job_title  \
# 0  Business Analyst  Technology & Operations Business Analyst
# 1  Business Analyst              Business Intelligence Intern
# 2  Business Analyst                               BI Engineer
# 3  Business Analyst                          Business Analyst
# 4  Business Analyst                        Commercial Analyst
#
#             job_location             job_via job_schedule_type  \
# 0    Copenhagen, Denmark     via Trabajo.org         Full-time
# 1             Dallas, TX        via LinkedIn         Full-time
# 2                Namibia  via Intellijobs.ai         Full-time
# 3  Tel Aviv-Yafo, Israel          via Comeet         Full-time
# 4           South Africa        via LinkedIn         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False               Denmark 2023-06-05 13:44:34
# 1               False  Texas, United States 2023-01-04 13:02:07
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Merge Company Salary and Remote Count (2.7.3)

# %%
df_company_salary = df.groupby('company_name')['salary_year_avg'].mean().reset_index()
df_company_remote = df[df['job_work_from_home'] == True]
df_company_remote = df_company_remote.groupby('company_name')['job_work_from_home'].size().reset_index(name='remote_count')
# df_company_remote.rename(columns={'job_work_from_home': 'remote_count'}, inplace=True)

merged_df = pd.merge(df_company_salary, df_company_remote, on='company_name', how='right')
merged_df.head(10)
# Out:
#                                        company_name  salary_year_avg  \
# 0                                       #EqualsTrue              NaN
# 1                                     #TeamGoHealth              NaN
# 2                           #twiceasnice Recruiting          77750.0
# 3                                             &Work              NaN
# 4         (AEG) Application Engineering Group, Inc.              NaN
# 5  (ISSA) International Sports Sciences Association              NaN
# 6                                   (주)직방 (ZIGBANG)              NaN
# 7                                             +OneX              NaN
# 8                          -  - Career Mentors, LLC              NaN
# 9                                      -  - DevGrid              NaN
#
#    remote_count
# 0             4
# 1             1
# 2             1
# 3             1
# 4             1
# 5             2
# 6             2
# 7             1
# 8             1
# 9             1

# %% [markdown]
# ---
