# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_29_Matplotlib Plotting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Job Country Bar Chart (1.29.1)

# %%
country_jobs = df.job_country.value_counts().head()
plt.bar(country_jobs.index, country_jobs)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Average Salary Horizontal Bar Chart (1.29.2)

# %%
avg_salary = df.groupby('job_title_short')['salary_year_avg'].mean()
avg_salary = avg_salary.sort_values(ascending=True)
plt.barh(avg_salary.index, avg_salary)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Average Salary Trend Line Plot (1.29.3)

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

monthly_avg_salary = df.groupby('job_posted_month')['salary_year_avg'].mean()
plt.plot(monthly_avg_salary.index, monthly_avg_salary)

# %% [markdown]
# ---
